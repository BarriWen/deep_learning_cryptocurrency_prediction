# %%
import tensorflow as tf
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import *
import matplotlib.pyplot as plt

# %%
# Build DataFrame
df = pd.read_csv("./Ethereum Historical Data.csv", thousands=",")
df = df.loc[:, ['Date', 'High', 'Low', 'Open', 'Vol', 'Price']]
df['Date'] = pd.to_datetime(df['Date'], format='%b %d, %Y')
df.set_index('Date', inplace=True)

# %%
# Parse Volume values from str to float
def parse_volume(value):
    if isinstance(value, str):
        if value == '-':
            return 0.0
        elif value.endswith('K'):
            return float(value.replace('K', '')) * 1e3
        elif value.endswith('M'):
            return float(value.replace('M', '')) * 1e6
        elif value.endswith('B'):
            return float(value.replace('B', '')) * 1e9
        else:
            return float(value)
    return value

df['Vol'] = df['Vol'].apply(parse_volume)

# %%
train_df = df.iloc[365:]
test_df = df.iloc[:365]

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(19, 10))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('Ethereum Price', fontsize=16)
    ax.legend(loc='best', fontsize=16)

aim = "Price"
line_plot(train_df[aim], test_df[aim], 'training', 'testing', title='')

# %%
scaler = MinMaxScaler(feature_range=(0, 1))
scaled_train_data = scaler.fit_transform(train_df[['High', 'Low', 'Open', 'Vol', 'Price']])
scaled_test_data = scaler.transform(test_df[['High', 'Low', 'Open', 'Vol', 'Price']])

# %%
def create_sequences(data, sequence_length):
    xs, ys = [], []
    for i in range(len(data) - sequence_length):
        x = data[i:(i + sequence_length)]
        y = data[i + sequence_length, -1]  # Price
        xs.append(x)
        ys.append(y)
    return np.array(xs), np.array(ys)

sequence_length = 60

# Create sequences for both training and testing data
X_train, y_train = create_sequences(scaled_train_data, sequence_length)
X_test, y_test = create_sequences(scaled_test_data, sequence_length)

# %%
model = Sequential([
    LSTM(50, return_sequences=True, input_shape=(X_train.shape[1], X_train.shape[2])),
    Dropout(0.2),
    LSTM(50, return_sequences=False),
    Dropout(0.2),
    Dense(25),
    Dense(1)
])
model.compile(optimizer='adam', loss='mean_squared_error')

# %%
model.fit(X_train, y_train, epochs=100, batch_size=32)
# Out:
# Epoch 1/100
# 69/69 [==============================] - 2s 16ms/step - loss: 0.0060
# Epoch 2/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0020
# Epoch 3/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 4/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0016
# Epoch 5/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0015
# Epoch 6/100
# 69/69 [==============================] - 1s 17ms/step - loss: 0.0012
# Epoch 7/100
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 8/100
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0011
# Epoch 9/100
# 69/69 [==============================] - 1s 17ms/step - loss: 9.8290e-04
# Epoch 10/100
# 69/69 [==============================] - 1s 17ms/step - loss: 9.2215e-04
# Epoch 11/100
# 69/69 [==============================] - 1s 17ms/step - loss: 9.2173e-04
# Epoch 12/100
# 69/69 [==============================] - 1s 16ms/step - loss: 8.2003e-04
# Epoch 13/100
# 69/69 [==============================] - 1s 16ms/step - loss: 9.1225e-04
# Epoch 14/100
# 69/69 [==============================] - 1s 16ms/step - loss: 8.8828e-04
# Epoch 15/100
# 69/69 [==============================] - 1s 17ms/step - loss: 8.9802e-04
# Epoch 16/100
# 69/69 [==============================] - 1s 16ms/step - loss: 0.0010
# Epoch 17/100
# 69/69 [==============================] - 1s 16ms/step - loss: 8.1439e-04
# Epoch 18/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.0225e-04
# Epoch 19/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.5731e-04
# Epoch 20/100
# 69/69 [==============================] - 1s 16ms/step - loss: 7.6227e-04
# Epoch 21/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.3509e-04
# Epoch 22/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.8096e-04
# Epoch 23/100
# 69/69 [==============================] - 1s 16ms/step - loss: 8.4341e-04
# Epoch 24/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.7798e-04
# Epoch 25/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.6327e-04
# Epoch 26/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.2740e-04
# Epoch 27/100
# 69/69 [==============================] - 1s 17ms/step - loss: 7.5629e-04
# Epoch 28/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.9282e-04
# Epoch 29/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.1776e-04
# Epoch 30/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.9038e-04
# Epoch 31/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.1967e-04
# Epoch 32/100
# 69/69 [==============================] - 1s 18ms/step - loss: 7.5689e-04
# Epoch 33/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.5040e-04
# Epoch 34/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4454e-04
# Epoch 35/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.0995e-04
# Epoch 36/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.6136e-04
# Epoch 37/100
# 69/69 [==============================] - 1s 18ms/step - loss: 6.5567e-04
# Epoch 38/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.8959e-04
# Epoch 39/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4342e-04
# Epoch 40/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.8637e-04
# Epoch 41/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.7679e-04
# Epoch 42/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.9439e-04
# Epoch 43/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.2619e-04
# Epoch 44/100
# 69/69 [==============================] - 1s 16ms/step - loss: 8.2145e-04
# Epoch 45/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.3385e-04
# Epoch 46/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.3824e-04
# Epoch 47/100
# 69/69 [==============================] - 1s 16ms/step - loss: 9.6146e-04
# Epoch 48/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.8859e-04
# Epoch 49/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.8247e-04
# Epoch 50/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.0299e-04
# Epoch 51/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.5479e-04
# Epoch 52/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.8539e-04
# Epoch 53/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.1284e-04
# Epoch 54/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.8296e-04
# Epoch 55/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4375e-04
# Epoch 56/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.5872e-04
# Epoch 57/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.4419e-04
# Epoch 58/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.8750e-04
# Epoch 59/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.5519e-04
# Epoch 60/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.7884e-04
# Epoch 61/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.6532e-04
# Epoch 62/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.7497e-04
# Epoch 63/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.2323e-04
# Epoch 64/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.5602e-04
# Epoch 65/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.7115e-04
# Epoch 66/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.4893e-04
# Epoch 67/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.7844e-04
# Epoch 68/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.1597e-04
# Epoch 69/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.7266e-04
# Epoch 70/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.1565e-04
# Epoch 71/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.6284e-04
# Epoch 72/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.8823e-04
# Epoch 73/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.2803e-04
# Epoch 74/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.9945e-04
# Epoch 75/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.3751e-04
# Epoch 76/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.3708e-04
# Epoch 77/100
# 69/69 [==============================] - 1s 17ms/step - loss: 6.1059e-04
# Epoch 78/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.7949e-04
# Epoch 79/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.3608e-04
# Epoch 80/100
# 69/69 [==============================] - 1s 17ms/step - loss: 5.0197e-04
# Epoch 81/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.9779e-04
# Epoch 82/100
# 69/69 [==============================] - 1s 17ms/step - loss: 4.4195e-04
# Epoch 83/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.0906e-04
# Epoch 84/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.9098e-04
# Epoch 85/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4871e-04
# Epoch 86/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.8546e-04
# Epoch 87/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.0305e-04
# Epoch 88/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.7501e-04
# Epoch 89/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.6549e-04
# Epoch 90/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.7760e-04
# Epoch 91/100
# 69/69 [==============================] - 1s 16ms/step - loss: 3.8208e-04
# Epoch 92/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.7768e-04
# Epoch 93/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.5079e-04
# Epoch 94/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.3905e-04
# Epoch 95/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.4520e-04
# Epoch 96/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.2101e-04
# Epoch 97/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.0256e-04
# Epoch 98/100
# 69/69 [==============================] - 1s 16ms/step - loss: 4.4612e-04
# Epoch 99/100
# 69/69 [==============================] - 1s 16ms/step - loss: 5.3954e-04
# Epoch 100/100
# 69/69 [==============================] - 1s 16ms/step - loss: 6.0500e-04

# %%
targets = test_df[aim][sequence_length:]
preds = model.predict(X_test).squeeze()

r2 = r2_score(y_test, preds)
mae = mean_absolute_error(preds, y_test)
mse = mean_squared_error(y_test, preds)
print("Mean Absolute Error (MAE):", mae)
print("Mean Squared Error (MSE):", mse)
print("R-squared Score (R2):", r2)
# Out:
# 10/10 [==============================] - 0s 4ms/step
# Mean Absolute Error (MAE): 0.005368011520480294
# Mean Squared Error (MSE): 4.905895251991975e-05
# R-squared Score (R2): 0.9849546694121026

# %%
preds = pd.Series(data=preds, index=targets.index)
preds = preds.to_numpy()
preds_2d = preds.reshape(-1,1)
original_data = scaler.inverse_transform(np.hstack([preds_2d, np.zeros((preds_2d.shape[0], 4))]))
original_data = original_data[:, 0]
result_df = pd.DataFrame(data=original_data, index=targets.index, columns=['Price'])
result_df = result_df.iloc[::-1]

line_plot(targets, result_df, 'actual', 'prediction', lw=3)
